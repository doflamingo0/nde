# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv('dataa.csv')

# %%
df
# Out:
#      Gen  Domain_idpc_ndu_302_12_4930  Node_idpc_ndu_302_12_4930  \
# 0      0                     0.333333                   0.191170
# 1      1                     0.394444                   0.256512
# 2      2                     0.327778                   0.186755
# 3      3                     0.388889                   0.237748
# 4      4                     0.338889                   0.188742
# ..   ...                          ...                        ...
# 495  495                     0.416667                   0.277483
# 496  496                     0.416667                   0.265121
# 497  497                     0.477778                   0.331567
# 498  498                     0.438889                   0.301766
# 499  499                     0.411111                   0.263355
#
#      Edge_idpc_ndu_302_12_4930  Domain_idpc_ndu_1002_12_82252  \
# 0                     0.135470                       0.288889
# ...

# %% [markdown]
# **idpc_ndu_2715_22_592246**

# %%
# Domain
f = plt.figure()
f.set_figwidth(20)
f.set_figheight(10)
plt.rcParams['font.size'] = 24
plt.title("Domain ratio of instance idpc_ndu_2715_22_592246")
plt.xlabel("Generation")
plt.ylabel("Ratio")
plt.plot(df.Gen, df.Domain_idpc_ndu_2715_22_592246)
plt.show()

# %%
# Node
f = plt.figure()
f.set_figwidth(20)
f.set_figheight(10)
plt.rcParams['font.size'] = 24
plt.title("Node ratio of instance idpc_ndu_2715_22_592246")
plt.xlabel("Generation")
plt.ylabel("Ratio")
plt.plot(df.Gen, df.Node_idpc_ndu_2715_22_592246)
plt.show()

# %%
# Edge
f = plt.figure()
f.set_figwidth(20)
f.set_figheight(10)
plt.rcParams['font.size'] = 24
plt.title("Edge ratio of instance idpc_ndu_2715_22_592246")
plt.xlabel("Generation")
plt.ylabel("Ratio")
plt.plot(df.Gen, df.Edge_idpc_ndu_2715_22_592246)
plt.show()

# %% [markdown]
# **idpc_ndu_2494_12_276620**

# %%
# Domain
f = plt.figure()
f.set_figwidth(20)
f.set_figheight(10)
plt.rcParams['font.size'] = 24
plt.title("Domain ratio of instance idpc_ndu_2494_12_276620")
plt.xlabel("Generation")
plt.ylabel("Ratio")
plt.plot(df.Gen, df.Domain_idpc_ndu_2494_12_276620)
plt.show()

# %%
# Node
f = plt.figure()
f.set_figwidth(20)
f.set_figheight(10)
plt.rcParams['font.size'] = 24
plt.title("Node ratio of instance idpc_ndu_2494_12_276620")
plt.xlabel("Generation")
plt.ylabel("Ratio")
plt.plot(df.Gen, df.Node_idpc_ndu_2494_12_276620)
plt.show()

# %%
# Edge
f = plt.figure()
f.set_figwidth(20)
f.set_figheight(10)
plt.rcParams['font.size'] = 24
plt.title("Edge ratio of instance idpc_ndu_2494_12_276620")
plt.xlabel("Generation")
plt.ylabel("Ratio")
plt.plot(df.Gen, df.Edge_idpc_ndu_2494_12_276620)
plt.show()

# %% [markdown]
# **idpc_ndu_1506_9_130556**

# %%
# Domain
f = plt.figure()
f.set_figwidth(20)
f.set_figheight(10)
plt.rcParams['font.size'] = 24
plt.title("Domain ratio of instance idpc_ndu_1506_9_130556")
plt.xlabel("Generation")
plt.ylabel("Ratio")
plt.plot(df.Gen, df.Domain_idpc_ndu_1506_9_130556)
plt.show()

# %%
# Node
f = plt.figure()
f.set_figwidth(20)
f.set_figheight(10)
plt.rcParams['font.size'] = 24
plt.title("Node ratio of instance idpc_ndu_1506_9_130556")
plt.xlabel("Generation")
plt.ylabel("Ratio")
plt.plot(df.Gen, df.Node_idpc_ndu_1506_9_130556)
plt.show()

# %%
# Edge
f = plt.figure()
f.set_figwidth(20)
f.set_figheight(10)
plt.rcParams['font.size'] = 24
plt.title("Edge ratio of instance idpc_ndu_1506_9_130556")
plt.xlabel("Generation")
plt.ylabel("Ratio")
plt.plot(df.Gen, df.Edge_idpc_ndu_1506_9_130556)
plt.show()

# %% [markdown]
# **idpc_ndu_1002_12_82252**

# %%
# Domain
f = plt.figure()
f.set_figwidth(20)
f.set_figheight(10)
plt.rcParams['font.size'] = 24
plt.title("Domain ratio of instance idpc_ndu_1002_12_82252")
plt.xlabel("Generation")
plt.ylabel("Ratio")
plt.plot(df.Gen, df.Domain_idpc_ndu_1002_12_82252)
plt.show()

# %%
# Node
f = plt.figure()
f.set_figwidth(20)
f.set_figheight(10)
plt.rcParams['font.size'] = 24
plt.title("Node ratio of instance idpc_ndu_1002_12_82252")
plt.xlabel("Generation")
plt.ylabel("Ratio")
plt.plot(df.Gen, df.Node_idpc_ndu_1002_12_82252)
plt.show()

# %%
# Edge
f = plt.figure()
f.set_figwidth(20)
f.set_figheight(10)
plt.rcParams['font.size'] = 24
plt.title("Edge ratio of instance idpc_ndu_1002_12_82252")
plt.xlabel("Generation")
plt.ylabel("Ratio")
plt.plot(df.Gen, df.Edge_idpc_ndu_1002_12_82252)
plt.show()

# %% [markdown]
# **idpc_ndu_302_12_4930**

# %%
# Domain
f = plt.figure()
f.set_figwidth(20)
f.set_figheight(10)
plt.rcParams['font.size'] = 24
plt.title("Domain ratio of instance idpc_ndu_302_12_4930")
plt.xlabel("Generation")
plt.ylabel("Ratio")
plt.plot(df.Gen, df.Domain_idpc_ndu_302_12_4930)
plt.show()

# %%
# Node
f = plt.figure()
f.set_figwidth(20)
f.set_figheight(10)

plt.rcParams['font.size'] = 24
plt.title("Node ratio of instance idpc_ndu_302_12_4930")
plt.xlabel("Generation")
plt.ylabel("Ratio")
plt.plot(df.Gen, df.Node_idpc_ndu_302_12_4930)
plt.show()

# %%
# Edge
f = plt.figure()
f.set_figwidth(20)
f.set_figheight(10)

plt.rcParams['font.size'] = 24
plt.title("Edge ratio of instance idpc_ndu_302_12_4930")
plt.xlabel("Generation")
plt.ylabel("Ratio")
plt.plot(df.Gen, df.Edge_idpc_ndu_302_12_4930)
plt.show()
